# %% [markdown]
# # Import the Libraries

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
import matplotlib.dates as mdates

# %%
from subprocess import check_output

# %% [markdown]
# # Reading the Data

# %%
funds = pd.read_csv('funds.csv')

# %%
funds.head()
# Out:
#   Agreement Number                                    Agreement Title  \
# 0          FK/4032                    Fredskorpset personell exchange
# 1    GLO-05/273-12  Primary school textbook production/Resource Ce...
# 2       TAN-08/073                               Africa Umoja Concert
# 3       06-2060235                   KS-Local Government Assoc in BIH
# 4       NGA-04/001                          INTSOK kurs i brønnboring
#
#                     Agreement Partner Group of Agreement Partner  \
# 0                   Strømmestiftelsen              NGO Norwegian
# 1                 Utdanningsforbundet              NGO Norwegian
# 2                Norsk Kulturskoleråd    Norwegian public sector
# 3  KS - Kommunesektorens organisasjon              NGO Norwegian
# 4                              INTSOK              NGO Norwegian
#
#                   Implementing Partner  \
# 0                    Strømmestiftelsen
# 1  PATC - Pan-African Teachers' Centre
# ...

# %%
funds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94310 entries, 0 to 94309
# Data columns (total 28 columns):
# Agreement Number                                                    94310 non-null object
# Agreement Title                                                     94310 non-null object
# Agreement Partner                                                   94310 non-null object
# Group of Agreement Partner                                          94310 non-null object
# Implementing Partner                                                94307 non-null object
# Description of Agreement                                            80633 non-null object
# Main Sector                                                         94310 non-null object
# Sub Sector                                                          94310 non-null object
# Target Area                                                         94310 non-null object
# ...

# %% [markdown]
# # Checking for Null Values

# %%
funds.isnull()
# Out:
#       Agreement Number Agreement Title Agreement Partner  \
# 0                False           False             False
# 1                False           False             False
# 2                False           False             False
# 3                False           False             False
# 4                False           False             False
# 5                False           False             False
# 6                False           False             False
# 7                False           False             False
# 8                False           False             False
# 9                False           False             False
# 10               False           False             False
# 11               False           False             False
# 12               False           False             False
# 13               False           False             False
# 14               False           False             False
# ...

# %%
sns.heatmap(funds.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
funds.drop('Unnamed: 27',axis=1,inplace=True)

# %%
sns.heatmap(funds.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# # Checking Back on the Summary

# %%
funds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94310 entries, 0 to 94309
# Data columns (total 27 columns):
# Agreement Number                                                    94310 non-null object
# Agreement Title                                                     94310 non-null object
# Agreement Partner                                                   94310 non-null object
# Group of Agreement Partner                                          94310 non-null object
# Implementing Partner                                                94307 non-null object
# Description of Agreement                                            80633 non-null object
# Main Sector                                                         94310 non-null object
# Sub Sector                                                          94310 non-null object
# Target Area                                                         94310 non-null object
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Year',y='Disbursements (1000 $)',data=funds)

# %%
plt.figure(figsize=(20,15))
sns.barplot(x='Recipient Region',y='Disbursements (1000 $)',data=funds)

# %%
plt.figure(figsize=(20,15))
sns.barplot(x='Target Area',y='Disbursements (1000 $)',data=funds)

# %%
plt.figure(figsize=(20,15))
sns.barplot(x='Target Area',y='Disbursements (1000 NOK)',data=funds)

# %%
plt.figure(figsize=(20,15))
sns.barplot(x='Type of Assistance',y='Disbursements (1000 $)',data=funds)

# %%
plt.figure(figsize=(20,15))
sns.boxplot(x='Main Sector',y='Disbursements (1000 $)',data=funds)
